# %% [markdown]
# # Data Analysis Day 1
# ## Mahmood Rasheed

# %%
# importing pandas library
import pandas as pd

# %%
# loading data from csv
df = pd.read_csv("diabetes.csv")

# %%
# printing data
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# name of all columns
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
# total observations and features
r,c = df.shape

print(f"Total observations are {r} and features are {c}")
# Out:
# Total observations are 768 and features are 9

# %%
# data type of age is
df['Age'].dtype
# Out:
# dtype('int64')

# %%
# top 10 rows
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
# bottom 10 rows
df.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
# 10 samples from data set
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 696            3      169             74             19      125  29.9
# 13             1      189             60             23      846  30.1
# 234            3       74             68             28       45  29.7
# 593            2       82             52             22      115  28.5
# 633            1      128             82             17      183  27.5
# 747            1       81             74             41       57  46.3
# 597            1       89             24             19       25  27.8
# 5              5      116             74              0        0  25.6
# 702            1      168             88             29        0  35.0
# 125            1       88             30             42       99  55.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 696                     0.268   31        1
# 13                      0.398   59        1
# 234                     0.293   23        0
# ...

# %%
# information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# total null values in each column
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# total duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# total unique values in each column
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# statitical summary of data
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# printing data of specific column from dataset

df["BMI"]
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 763    32.9
# 764    36.8
# 765    26.2
# 766    30.1
# 767    30.4
# Name: BMI, Length: 768, dtype: float64

# %%
# printing multiple columns from dataset
df[["BMI", "Age", "Outcome"]]
# Out:
#       BMI  Age  Outcome
# 0    33.6   50        1
# 1    26.6   31        0
# 2    23.3   32        1
# 3    28.1   21        0
# 4    43.1   33        1
# ..    ...  ...      ...
# 763  32.9   63        0
# 764  36.8   27        0
# 765  26.2   30        0
# 766  30.1   47        1
# 767  30.4   23        0
#
# [768 rows x 3 columns]

# %%
# all patients who donn't have diabetes
df[df["Outcome"]==0]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1              1       85             66             29        0  26.6
# 3              1       89             66             23       94  28.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# 10             4      110             92              0        0  37.6
# ..           ...      ...            ...            ...      ...   ...
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 1                       0.351   31        0
# ...

# %%
# all patients who have diabetes
df[df["Outcome"] == 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# all patients whose age is greater than 40
df[df["Age"]>40]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# minimum age of patient who is suffering from diabetes
min(df[df["Outcome"] == 1]["Age"])
# Out:
# 21

# %%
# maximum age of patient who is suffering from diabetes
max(df[df["Outcome"] == 1]["Age"])
# Out:
# 70

# %% [markdown]
# ## General information about this data set
#
# - This dataset contains 768 observations and 9 features.
# - There is no null value in this dataset
# - There is no duplicate observation in this dataset
# - Average BMI in this dataset is 31.99.
# - Avergae Age in this dataset is 33.24.
# - Minimum age of patient who is suffering from diabetes is 21.
# - Maximum age of patient who is suffering from diabetes is 70.

# %% [markdown]
# ## Insights
# - This dataset contains record of 768 patients. 500 people are not suffering from diabetes and remaining 268 people are suffering from diabetes, from which 194 patients are above 40.
#
# - Individuals over the age of 40 should prioritize their health by undergoing regular screenings for diabetes.
